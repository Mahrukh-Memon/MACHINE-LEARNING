# %%
import pandas as pd
file=pd.read_csv("iris.csv")
file
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
file.head()
file
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
file.isnull().sum()
# file.isna().sum()
# file
# Out:
# 5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %%
file.dtypes
# Out:
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
file.columns=["sepal_length","sepal_width","petal_length","petal_width","specie"]
file
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          specie
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# val_count=file.nunique()
# print(val_count)
file["specie"].value_counts()
# Out:
# specie
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64

# %%
max_val=file.max()
print(max_val)
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# specie          Iris-virginica
# dtype: object

# %%
min_val=file.min()
print(min_val)
# Out:
# sepal_length            4.3
# sepal_width             2.0
# petal_length            1.0
# petal_width             0.1
# specie          Iris-setosa
# dtype: object

# %%
file["specie"].value_counts()
# Out:
# specie
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
file['specie']=label.fit_transform(file['specie'])
file.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  specie
# 0           4.9          3.0           1.4          0.2       0
# 1           4.7          3.2           1.3          0.2       0
# 2           4.6          3.1           1.5          0.2       0
# 3           5.0          3.6           1.4          0.2       0
# 4           5.4          3.9           1.7          0.4       0

# %%
x=file.drop('specie',axis=1)
y=file['specie']

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             4.9          3.0           1.4          0.2
# 1             4.7          3.2           1.3          0.2
# 2             4.6          3.1           1.5          0.2
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# ..            ...          ...           ...          ...
# 144           6.7          3.0           5.2          2.3
# 145           6.3          2.5           5.0          1.9
# 146           6.5          3.0           5.2          2.0
# 147           6.2          3.4           5.4          2.3
# 148           5.9          3.0           5.1          1.8
#
# [149 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 144    2
# 145    2
# 146    2
# 147    2
# 148    2
# Name: specie, Length: 149, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dt_classifier=DecisionTreeClassifier(random_state=42)
dt_classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
x_test.head()
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 1087  39385    748.882       258.745821       194.255915      1.331984
# 5909  82769   1102.587       419.758999       252.883510      1.659891
# 6141  47463    817.819       303.341316       199.819948      1.518073
# 9484  45755    800.907       295.816101       197.832721      1.495284
# 7631  45363    779.489       287.103832       201.869869      1.422222
#
#       Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 1087      0.660575       39895     223.934230  0.767111  0.987216   0.882498
# 5909      0.798157       84000     324.630196  0.707815  0.985345   0.855563
# 6141      0.752380       47902     245.828738  0.795025  0.990835   0.891765
# 9484      0.743470       46287     241.365025  0.803664  0.988506   0.896364
# 7631      0.711066       45774     240.328869  0.818236  0.991021   0.938192
#
#       Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# ...

# %%
dt_classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
x_test.shape
# Out:
# (1906, 16)

# %%
y_pred=dt_classifier.predict(x_test)
y_pred
# Out:
# array(['SEKER', 'CALI', 'SIRA', ..., 'HOROZ', 'SEKER', 'CALI'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8898216159496327

# %%
test=pd.read_csv("Test.csv")
train=pd.read_csv("Train.csv")
test
train
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0     54180    951.753       388.728347       178.948203      2.172295
# 1     42023    746.715       272.962686       196.334047      1.390297
# 2     38600    716.517       254.129288       193.991641      1.310001
# 3     62298    992.583       327.685094       242.658033      1.350399
# 4     74456   1085.466       447.665972       212.382328      2.107831
# ...     ...        ...              ...              ...           ...
# 9523  55381    914.969       363.142352       194.498350      1.867072
# 9524  40987    749.125       272.565043       192.210719      1.418053
# 9525  32168    663.090       239.983107       171.160719      1.402092
# 9526  53228    920.083       380.325304       178.969940      2.125079
# 9527  50330    841.897       324.437513       198.042350      1.638223
#
#       Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
test.shape
# Out:
# (4083, 17)

# %%
train.shape
# Out:
# (9528, 17)

# %%
test.describe()
# Out:
#                 Area    Perimeter  MajorAxisLength  MinorAxisLength  \
# count    4083.000000  4083.000000      4083.000000      4083.000000
# mean    52564.673524   852.033817       319.137432       201.298586
# std     28645.358590   211.126243        84.442374        44.334712
# min     20420.000000   524.932000       183.601165       132.187521
# 25%     36087.000000   701.621500       252.660111       174.761997
# 50%     44453.000000   791.480000       296.398632       191.664022
# 75%     61035.000000   974.456000       375.418250       216.783314
# max    237270.000000  1921.685000       738.144502       449.339678
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter       Extent  \
# count   4083.000000   4083.000000    4083.000000    4083.000000  4083.000000
# mean       1.585725      0.752378   53283.909870     252.055118     0.748994
# std        0.244526      0.090468   29077.775196      58.279243     0.048860
# ...

# %%
train.describe
train
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0     54180    951.753       388.728347       178.948203      2.172295
# 1     42023    746.715       272.962686       196.334047      1.390297
# 2     38600    716.517       254.129288       193.991641      1.310001
# 3     62298    992.583       327.685094       242.658033      1.350399
# 4     74456   1085.466       447.665972       212.382328      2.107831
# ...     ...        ...              ...              ...           ...
# 9523  55381    914.969       363.142352       194.498350      1.867072
# 9524  40987    749.125       272.565043       192.210719      1.418053
# 9525  32168    663.090       239.983107       171.160719      1.402092
# 9526  53228    920.083       380.325304       178.969940      2.125079
# 9527  50330    841.897       324.437513       198.042350      1.638223
#
#       Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
test.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
test["Class"].nunique()
# Out:
# 7

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
train['Class']=label.fit_transform(train['Class'])
train.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  54180    951.753       388.728347       178.948203      2.172295
# 1  42023    746.715       272.962686       196.334047      1.390297
# 2  38600    716.517       254.129288       193.991641      1.310001
# 3  62298    992.583       327.685094       242.658033      1.350399
# 4  74456   1085.466       447.665972       212.382328      2.107831
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.887741       55014     262.648279  0.580210  0.984840   0.751624
# 1      0.694730       42365     231.312225  0.795348  0.991927   0.947081
# 2      0.645976       38940     221.691331  0.715265  0.991269   0.944809
# 3      0.672032       63353     281.638558  0.801157  0.983347   0.794603
# 4      0.880298       75096     307.896612  0.788821  0.991478   0.794104
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
x=train.drop(['Class'],axis=1)
y=train['Class']
y
# Out:
# 0       4
# 1       3
# 2       5
# 3       0
# 4       4
#        ..
# 9523    4
# 9524    6
# 9525    3
# 9526    4
# 9527    6
# Name: Class, Length: 9528, dtype: int32

# %%
x
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0     54180    951.753       388.728347       178.948203      2.172295
# 1     42023    746.715       272.962686       196.334047      1.390297
# 2     38600    716.517       254.129288       193.991641      1.310001
# 3     62298    992.583       327.685094       242.658033      1.350399
# 4     74456   1085.466       447.665972       212.382328      2.107831
# ...     ...        ...              ...              ...           ...
# 9523  55381    914.969       363.142352       194.498350      1.867072
# 9524  40987    749.125       272.565043       192.210719      1.418053
# 9525  32168    663.090       239.983107       171.160719      1.402092
# 9526  53228    920.083       380.325304       178.969940      2.125079
# 9527  50330    841.897       324.437513       198.042350      1.638223
#
#       Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model=DecisionTreeClassifier(random_state=10)

# %%
dt_model.fit(x, y)
# Out:
# DecisionTreeClassifier(random_state=10)

# %%
train_pred=dt_model.predict(x)
train_pred
# Out:
# array([4, 3, 5, ..., 3, 4, 6])

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(y,train_pred)
print(acc)
# Out:
# 1.0

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
test['Class']=label.fit_transform(test['Class'])
test.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  29380    624.110       212.826130       175.931143      1.209713
# 1  30008    645.884       210.557999       182.516516      1.153638
# 2  30279    634.927       212.560556       181.510182      1.171067
# 3  31107    640.594       214.648549       184.969253      1.160455
# 4  31203    639.782       215.067737       184.874876      1.163315
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 1      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 2      0.520401       30600     196.347702  0.775688  0.989510   0.943852
# 3      0.507366       31423     199.014227  0.761046  0.989944   0.952582
# 4      0.510947       31558     199.321081  0.762984  0.988751   0.957949
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
x=test.drop(['Class'],axis=1)
y=test['Class']
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 4078    3
# 4079    3
# 4080    3
# 4081    3
# 4082    3
# Name: Class, Length: 4083, dtype: int32

# %%
x
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0     29380    624.110       212.826130       175.931143      1.209713
# 1     30008    645.884       210.557999       182.516516      1.153638
# 2     30279    634.927       212.560556       181.510182      1.171067
# 3     31107    640.594       214.648549       184.969253      1.160455
# 4     31203    639.782       215.067737       184.874876      1.163315
# ...     ...        ...              ...              ...           ...
# 4078  41979    757.238       272.579920       196.580706      1.386606
# 4079  42008    759.454       280.332717       191.218136      1.466036
# 4080  42012    778.043       297.912812       179.711836      1.657725
# 4081  42070    760.701       276.691651       193.945366      1.426647
# 4082  42101    757.499       281.576392       190.713136      1.476439
#
#       Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model=DecisionTreeClassifier(random_state=10)

# %%
dt_model.fit(x, y)
# Out:
# DecisionTreeClassifier(random_state=10)

# %%
test_pred=dt_model.predict(x)
test_pred
# Out:
# array([5, 5, 5, ..., 3, 3, 3])

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(y,test_pred)
print(acc)
# Out:
# 1.0
